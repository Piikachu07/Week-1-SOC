# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Hp\Desktop\machine learning\framingham.csv")

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df = df.iloc[:,1:]

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0   39        4.0              0         0.0     0.0                0
# 1   46        2.0              0         0.0     0.0                0
# 2   48        1.0              1        20.0     0.0                0
# 3   61        3.0              1        30.0     0.0                0
# 4   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# ...

# %%
df.shape
# Out:
# (4238, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              4238 non-null   int64
#  1   education        4133 non-null   float64
#  2   currentSmoker    4238 non-null   int64
#  3   cigsPerDay       4209 non-null   float64
#  4   BPMeds           4185 non-null   float64
#  5   prevalentStroke  4238 non-null   int64
#  6   prevalentHyp     4238 non-null   int64
#  7   diabetes         4238 non-null   int64
#  8   totChol          4188 non-null   float64
#  9   sysBP            4238 non-null   float64
#  10  diaBP            4238 non-null   float64
#  11  BMI              4219 non-null   float64
#  12  heartRate        4237 non-null   float64
#  13  glucose          3850 non-null   float64
#  14  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(6)
# memory usage: 496.8 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['currentSmoker'],df['diabetes'],c=df['TenYearCHD'])

# %%
x = df.iloc[:,0:14]

# %%
x
# Out:
#       age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0      39        4.0              0         0.0     0.0                0
# 1      46        2.0              0         0.0     0.0                0
# 2      48        1.0              1        20.0     0.0                0
# 3      61        3.0              1        30.0     0.0                0
# 4      46        3.0              1        23.0     0.0                0
# ...   ...        ...            ...         ...     ...              ...
# 4231   58        3.0              0         0.0     0.0                0
# 4232   68        1.0              0         0.0     0.0                0
# 4233   50        1.0              1         1.0     0.0                0
# 4234   51        3.0              1        43.0     0.0                0
# 4237   52        2.0              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# ...

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4231    0
# 4232    1
# 4233    1
# 4234    0
# 4237    0
# Name: TenYearCHD, Length: 3656, dtype: int64

# %%
# Now we will split the data to 90 percent of the data for the model train and 10 percent for the to test the data
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size = 0.1)

# %%
X_train
# Out:
#       age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 1708   49        2.0              1        11.0     0.0                0
# 2084   48        1.0              0         0.0     0.0                0
# 284    68        1.0              0         0.0     0.0                0
# 2345   64        1.0              1        30.0     0.0                0
# 533    53        2.0              0         0.0     0.0                0
# ...   ...        ...            ...         ...     ...              ...
# 406    43        3.0              0         0.0     0.0                0
# 623    50        3.0              1         3.0     0.0                0
# 157    49        1.0              0         0.0     0.0                0
# 2672   51        1.0              1        15.0     0.0                0
# 1237   61        1.0              1        20.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# ...

# %%
X_test
# Out:
#       age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 2072   62        3.0              1        20.0     0.0                0
# 703    47        3.0              0         0.0     0.0                0
# 194    42        3.0              0         0.0     0.0                0
# 3457   52        4.0              0         0.0     0.0                0
# 409    44        1.0              1        10.0     0.0                0
# ...   ...        ...            ...         ...     ...              ...
# 2461   65        1.0              0         0.0     0.0                1
# 3680   47        2.0              1        20.0     0.0                0
# 4134   46        1.0              1        20.0     0.0                0
# 3267   44        1.0              1        20.0     0.0                0
# 1772   55        4.0              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# ...

# %%
Y_test
# Out:
# 2072    0
# 703     0
# 194     1
# 3457    0
# 409     0
#        ..
# 2461    1
# 3680    1
# 4134    0
# 3267    0
# 1772    0
# Name: TenYearCHD, Length: 366, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()

# %%
X_train = Scaler.fit_transform(X_train)

# %%
X_test = Scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 1.53376736,  1.08720869,  1.0856203 , ..., -0.54004582,
#         -0.36856804, -0.3954754 ],
#        [-0.32503679,  1.08720869, -0.92113237, ...,  0.77018385,
#          0.49228648, -0.23737163],
#        [-0.94463817,  1.08720869, -0.92113237, ..., -0.69449332,
#         -0.36856804, -0.43500134],
#        ...,
#        [-0.44895707, -0.93782123,  1.0856203 , ...,  1.76894439,
#          0.32011557, -0.43500134],
#        [-0.69679762, -0.93782123,  1.0856203 , ..., -0.03036905,
#         -0.11031169, -0.5931051 ],
#        [ 0.66632542,  2.09972365, -0.92113237, ...,  0.30684134,
#         -2.26244798,  0.2764656 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#model training
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_predict = clf.predict(X_test)

# %%
Y_test
# Out:
# 2072    0
# 703     0
# 194     1
# 3457    0
# 409     0
#        ..
# 2461    1
# 3680    1
# 4134    0
# 3267    0
# 1772    0
# Name: TenYearCHD, Length: 366, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
# accuracy of the model 
accuracy_score(Y_test,Y_predict)
# Out:
# 0.860655737704918
